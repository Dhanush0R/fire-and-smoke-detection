# %%
print("YOLOv10")
# Out:
# YOLOv10

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...

# %%
cd yolov10
# Out:
# E:\JN\yolov10
# C:\Users\danud\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install .
# Out:
# Processing e:\jn\yolov10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#      ----                                     0.1/1.2 MB 3.6 MB/s eta 0:00:01
#      ---------                                0.3/1.2 MB 3.4 MB/s eta 0:00:01
#      ---------------                          0.5/1.2 MB 3.5 MB/s eta 0:00:01
#      ------------------------                 0.7/1.2 MB 4.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 5.4 MB/s eta 0:00:00
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded E:\JN\yolov10\weights\yolov10n.pt
# Downloaded E:\JN\yolov10\weights\yolov10s.pt

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10n.pt source=../test_images/9.jpg
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.10.11 torch-2.3.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# YOLOv10n summary (fused): 285 layers, 2762608 parameters, 63840 gradients, 8.6 GFLOPs
#
# image 1/1 E:\JN\yolov10\..\test_images\9.jpg: 384x640 1 0, 1 68, 2 71s, 1 72, 93.7ms
# Speed: 0.0ms preprocess, 93.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to E:\JN\yolov10\runs\detect\predict
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %%
pip install huggingface_hub
# Out:
# ...
#      ---------------------------------------- 0.0/402.6 kB ? eta -:--:--
#      ----- --------------------------------- 61.4/402.6 kB 1.7 MB/s eta 0:00:01
#      ------------------------ ------------- 256.0/402.6 kB 4.0 MB/s eta 0:00:01
#      -------------------------------------- 402.6/402.6 kB 4.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.1.1
# [notice] To update, run: C:\Users\danud\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLOv10

# %%
model = YOLOv10("../weights/yolov10n.pt")

# %%
r = model("../test_images/Fire (145).jpeg")
# Out:
# image 1/1 E:\JN\yolov10\..\test_images\Fire (145).jpeg: 480x640 (no detections), 98.8ms
# Speed: 0.0ms preprocess, 98.8ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)

# %%
# !yolo task=detect mode=train epochs=25 batch=16 plots=True model=../weights/yolov10n.pt data=../fns_small/data.yaml
# Out:
# train: Scanning E:\JN\fns_small\train\labels.cache... 556 images, 0 backgrounds, 0 corrupt: 100%|##########| 556/556 [00:00<?, ?it/s]
# train: Scanning E:\JN\fns_small\train\labels.cache... 556 images, 0 backgrounds, 0 corrupt: 100%|##########| 556/556 [00:00<?, ?it/s]
#
# val: Scanning E:\JN\fns_small\valid\labels.cache... 105 images, 0 backgrounds, 0 corrupt: 100%|##########| 105/105 [00:00<?, ?it/s]
# val: Scanning E:\JN\fns_small\valid\labels.cache... 105 images, 0 backgrounds, 0 corrupt: 100%|##########| 105/105 [00:00<?, ?it/s]
#
#   0%|          | 0/35 [00:00<?, ?it/s]
#        1/25         0G      2.096      3.609      1.925      1.928      5.924      1.664         67        640:   0%|          | 0/35 [00:07<?, ?it/s]
#        1/25         0G      2.096      3.609      1.925      1.928      5.924      1.664         67        640:   3%|2         | 1/35 [00:07<04:25,  7.81s/it]
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=../yolov10/runs/detect/train2/weights/best.pt source=E:\JN\test_images\fire3.mp4
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.10.11 torch-2.3.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# YOLOv10n summary (fused): 285 layers, 2695196 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 100.0ms
# video 1/1 (frame 2/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 92.0ms
# video 1/1 (frame 3/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 92.0ms
# video 1/1 (frame 4/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 88.0ms
# video 1/1 (frame 5/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 88.0ms
# video 1/1 (frame 6/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 92.0ms
# video 1/1 (frame 7/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 92.0ms
# video 1/1 (frame 8/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 94.0ms
# video 1/1 (frame 9/1929) E:\JN\test_images\fire3.mp4: 384x640 (no detections), 92.0ms
# ...

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
import tensorflow as tf

# %%
''
